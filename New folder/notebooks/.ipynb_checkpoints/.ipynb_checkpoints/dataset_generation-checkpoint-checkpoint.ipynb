# %%
import pandas as pd
import numpy as np

# %%
n = 5000

# %%
np.random.seed(42)

data = {
    "area_type": np.random.choice(["Residential", "Commercial", "Public"], n),
    "time_of_day": np.random.choice(["Morning", "Evening", "Night"], n),
    "day_of_week": np.random.choice(["Weekday", "Weekend"], n),
    "past_incidents": np.random.randint(0, 20, n),
    "police_presence": np.random.choice(["Low", "Medium", "High"], n),
    "lighting": np.random.choice(["Poor", "Average", "Good"], n),
    "crowd_density": np.random.choice(["Low", "Medium", "High"], n)
}

# %%
risk = []

for i in range(n):
    score = 0
    
    if data["past_incidents"][i] > 10:
        score += 2
    if data["time_of_day"][i] == "Night":
        score += 1
    if data["lighting"][i] == "Poor":
        score += 1
    if data["police_presence"][i] == "Low":
        score += 1
    
    if score >= 4:
        risk.append(2)   # High
    elif score >= 2:
        risk.append(1)   # Medium
    else:
        risk.append(0)   # Low

# %%
df = pd.DataFrame(data)
df["risk_level"] = risk

df.head()
# Out:
#      area_type time_of_day day_of_week  past_incidents police_presence  \
# 0       Public       Night     Weekday               9             Low
# 1  Residential     Morning     Weekend              11             Low
# 2       Public       Night     Weekend               1          Medium
# 3       Public     Morning     Weekend               9            High
# 4  Residential       Night     Weekday              19          Medium
#
#   lighting crowd_density  risk_level
# 0     Good          High           1
# 1  Average           Low           1
# 2  Average        Medium           0
# 3  Average          High           0
# 4  Average          High           1

# %%
df.to_csv("women_safety_data.csv", index=False)

# %%
df
# Out:
#         area_type time_of_day day_of_week  past_incidents police_presence  \
# 0          Public       Night     Weekday               9             Low
# 1     Residential     Morning     Weekend              11             Low
# 2          Public       Night     Weekend               1          Medium
# 3          Public     Morning     Weekend               9            High
# 4     Residential       Night     Weekday              19          Medium
# ...           ...         ...         ...             ...             ...
# 4995  Residential       Night     Weekday              18            High
# 4996   Commercial     Morning     Weekend              10            High
# 4997       Public     Evening     Weekend              12            High
# 4998   Commercial     Evening     Weekday               7          Medium
# 4999  Residential       Night     Weekday               6            High
#
#      lighting crowd_density  risk_level
# 0        Good          High           1
# 1     Average           Low           1
# 2     Average        Medium           0
# 3     Average          High           0
# 4     Average          High           1
# ...       ...           ...         ...
# 4995  Average           Low           1
# 4996  Average          High           0
# 4997     Poor           Low           1
# 4998     Good        Medium           0
# 4999  Average           Low           0
#
# [5000 rows x 8 columns]
